# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer_df= pd.read_csv('../data/clean_data/customer.csv')
geolocation_df= pd.read_csv('../data/clean_data/geolocation.csv')
order_items_df= pd.read_csv('../data/clean_data/order_items.csv')
order_payments_df= pd.read_csv('../data/clean_data/order_payments.csv')
order_reviews_df= pd.read_csv('../data/clean_data/order_reviews.csv')
orders_df= pd.read_csv('../data/clean_data/orders.csv')
product_category_df= pd.read_csv('../data/clean_data/product_category.csv')
products_df= pd.read_csv('../data/clean_data/products.csv')     
seller_df= pd.read_csv('../data/clean_data/sellers.csv')

# %% [markdown]
# # Single DataFrames (Intermediate Relationship Merges)

# %% [markdown]
# 1. Customers With Orders

# %%
customer_orders=pd.merge(
  customer_df,
  orders_df,
  on='customer_id',
  how='left'
)

# %%
customer_orders.columns
# Out:
# Index(['Unnamed: 0', 'customer_id', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'order_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_days', 'delivery_days_only'],
#       dtype='str')

# %%
customer_orders.isnull().mean()*100
# Out:
# Unnamed: 0                       0.000000
# customer_id                      0.000000
# customer_unique_id               0.000000
# customer_zip_code_prefix         0.000000
# customer_city                    0.000000
# customer_state                   0.000000
# order_id                         0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.160899
# order_delivered_carrier_date     0.000000
# order_delivered_customer_date    0.000000
# order_estimated_delivery_date    0.000000
# delivery_days                    0.000000
# delivery_days_only               0.000000
# dtype: float64

# %% [markdown]
# 2. Orders with Orders_items (Using Inner Join for that to show Match relationship between the,)

# %%
orders_orders_items_merged=pd.merge(
    orders_df,
    order_items_df,
    on='order_id',
    how='inner'
)

# %%
orders_orders_items_merged.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_days', 'delivery_days_only', 'Unnamed: 0', 'order_item_id',
#        'product_id', 'seller_id', 'shipping_limit_date', 'price',
#        'freight_value'],
#       dtype='str')

# %%
orders_orders_items_merged.isnull().mean()*100
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.013316
# order_delivered_carrier_date     0.000000
# order_delivered_customer_date    0.000000
# order_estimated_delivery_date    0.000000
# delivery_days                    0.000000
# delivery_days_only               0.000000
# Unnamed: 0                       0.000000
# order_item_id                    0.000000
# product_id                       0.000000
# seller_id                        0.000000
# shipping_limit_date              0.000000
# price                            0.000000
# freight_value                    0.000000
# dtype: float64

# %% [markdown]
# 3. Orders with Orders_payments (Using Inner Join for that to show Match relationship between them)

# %%
order_order_payments_merged=pd.merge(
    orders_df,
    order_payments_df,
    on='order_id',
    how='inner'
)

# %%
order_order_payments_merged.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_days', 'delivery_days_only', 'Unnamed: 0',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value'],
#       dtype='str')

# %%
order_order_payments_merged.isnull().mean()*100
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.168454
# order_delivered_carrier_date     0.000000
# order_delivered_customer_date    0.000000
# order_estimated_delivery_date    0.000000
# delivery_days                    0.000000
# delivery_days_only               0.000000
# Unnamed: 0                       0.000000
# payment_sequential               0.000000
# payment_type                     0.000000
# payment_installments             0.000000
# payment_value                    0.000000
# dtype: float64

# %% [markdown]
# 4. Orders with Orders_Reviews (Using Left Join for that to show
# all left table value and mathch row from both side because all orders have not reviews)

# %%
orders_orders_reviews_merged=pd.merge(
    orders_df,
    order_reviews_df,
    on='order_id',
    how='left'
)

# %%
orders_orders_reviews_merged.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_days', 'delivery_days_only', 'Unnamed: 0', 'review_id',
#        'review_score', 'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='str')

# %%
orders_orders_reviews_merged.isnull().mean()*100
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.161013
# order_delivered_carrier_date     0.000000
# order_delivered_customer_date    0.000000
# order_estimated_delivery_date    0.000000
# delivery_days                    0.000000
# delivery_days_only               0.000000
# Unnamed: 0                       0.768061
# review_id                        0.768061
# review_score                     0.768061
# review_comment_title             0.768061
# review_comment_message           0.768061
# review_creation_date             0.768061
# review_answer_timestamp          0.768061
# dtype: float64

# %% [markdown]
# 5. Order-items with products (Using INNER Join for that to show Rlationship between Both Table)

# %%
order_items_df_products_merged=pd.merge(
    order_items_df,
    products_df,
    on='product_id',
    how='inner'
)

# %%
order_items_df_products_merged.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='str')

# %%
order_items_df_products_merged.isnull().mean()*100
# Out:
# Unnamed: 0                    0.000000
# order_id                      0.000000
# order_item_id                 0.000000
# product_id                    0.000000
# seller_id                     0.000000
# shipping_limit_date           0.000000
# price                         0.000000
# freight_value                 0.000000
# product_category_name         0.000000
# product_name_lenght           0.000000
# product_description_lenght    0.000000
# product_photos_qty            0.000000
# product_weight_g              0.015979
# product_length_cm             0.015979
# product_height_cm             0.015979
# product_width_cm              0.015979
# dtype: float64

# %% [markdown]
# 6. products with products-category-name (Using INNER Join for that to show Rlationship between Both Table)

# %%
products_products_category_merged=pd.merge(
    products_df,
    product_category_df,
    on='product_category_name',
    how='inner'
)

# %%
products_products_category_merged.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english'],
#       dtype='str')

# %%
products_products_category_merged.isnull().mean()*100
# Out:
# product_id                       0.000000
# product_category_name            0.000000
# product_name_lenght              0.000000
# product_description_lenght       0.000000
# product_photos_qty               0.000000
# product_weight_g                 0.006072
# product_length_cm                0.006072
# product_height_cm                0.006072
# product_width_cm                 0.006072
# product_category_name_english    0.000000
# dtype: float64

# %% [markdown]
# 7. Orders_items with sellers (Using INNER Join for that to show Rlationship between Both Table)

# %%
orders_items_sellers_merged=pd.merge(
    order_items_df,
    seller_df,
    on='seller_id',
    how='inner'
)

# %%
orders_items_sellers_merged.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state'],
#       dtype='str')

# %%
orders_items_sellers_merged.isnull().mean()*100
# Out:
# Unnamed: 0                0.0
# order_id                  0.0
# order_item_id             0.0
# product_id                0.0
# seller_id                 0.0
# shipping_limit_date       0.0
# price                     0.0
# freight_value             0.0
# seller_zip_code_prefix    0.0
# seller_city               0.0
# seller_state              0.0
# dtype: float64

# %% [markdown]
# 8. customers with Geolocation (Using Left Join for that to show
# all left table value and mathch row from both side because all orders have not reviews)

# %%
customers_geolocation_merged = pd.merge(
    customer_df,
    geolocation_df,
    left_on="customer_zip_code_prefix",
    right_on="geolocation_zip_code_prefix",
    how="left"
)

# %%
customers_geolocation_merged.columns
# Out:
# Index(['Unnamed: 0_x', 'customer_id', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'Unnamed: 0_y', 'geolocation_zip_code_prefix', 'geolocation_lat',
#        'geolocation_lng', 'geolocation_city', 'geolocation_state'],
#       dtype='str')

# %%
customers_geolocation_merged.isnull().mean()*100
# Out:
# Unnamed: 0_x                   0.000000
# customer_id                    0.000000
# customer_unique_id             0.000000
# customer_zip_code_prefix       0.000000
# customer_city                  0.000000
# customer_state                 0.000000
# Unnamed: 0_y                   0.002692
# geolocation_zip_code_prefix    0.002692
# geolocation_lat                0.002692
# geolocation_lng                0.002692
# geolocation_city               0.002692
# geolocation_state              0.002692
# dtype: float64

# %% [markdown]
# # Master DataFrame (Final Pipeline Concept)

# %% [markdown]
# Pipline/ Chaining (Understanding data Format and Build Pipeline of that)
#
# Customers --> Orders (Order_items,reviews,payemnts [For Debugging Choose those one that have relationship with others]) --> Order_item --> products --> Products_Category --> sellers --> reviews --> Payments --> Geolocation

# %%
# 1. Base Entity
master_df=customer_df

# %%
# 2. orders
master_df=pd.merge(
    master_df,
    orders_df,
    on='customer_id',
    how='left'
)

# %%
# 3. orders_items
master_df=pd.merge(
    master_df,
    order_items_df,
    on='order_id',
    how='left'
)

# %%
# 4. Products
master_df=pd.merge(
    master_df,
    products_df,
    on='product_id',
    how='left'
)

# %%
# 5. Products Category
master_df=pd.merge(
    master_df,
    product_category_df,
    on='product_category_name',
    how='left'
)

# %%
# 6. Sellers
master_df=pd.merge(
    master_df,
    seller_df,
    on='seller_id',
    how='left'
)

# %%
# Remove useless column BEFORE merging
master_df = master_df.drop(columns=["Unnamed: 0"], errors="ignore")
order_reviews_df = order_reviews_df.drop(columns=["Unnamed: 0"], errors="ignore")

# %%
# 7. Reviews
master_df=pd.merge(
    master_df,
    order_reviews_df,
    on='order_id',
    how='left'
)

# %%
# 8. Payments
master_df=pd.merge(
    master_df,
    order_payments_df,
    on='order_id',
    how='left'
)

# %%
# Remove useless column BEFORE merging
geolocation_df = geolocation_df.drop(columns=["Unnamed: 0"], errors="ignore")

# %%
# 9. Geolocation
master_df=pd.merge(
    master_df,
   geolocation_df,
    left_on='customer_zip_code_prefix',
    right_on='geolocation_zip_code_prefix',
    how='left'
)

# %%
master_df.columns
# Out:
# Index(['Unnamed: 0_x', 'customer_id', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'order_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_days', 'delivery_days_only', 'Unnamed: 0_y', 'order_item_id',
#        'product_id', 'seller_id', 'shipping_limit_date', 'price',
#        'freight_value', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'Unnamed: 0',
# ...

# %% [markdown]
# # MASTER DATASET FIX

# %%
# 1. REMOVE UNNAMED COLUMNS
master_df = master_df.loc[:, ~master_df.columns.str.contains("^Unnamed")]

# %%
# 2. HANDLE DUPLICATE REVIEW COLUMNS
# (keep one clean review_score column)

master_df["review_score"] = master_df["review_score_x"].fillna(master_df["review_score_y"])

master_df.drop(columns=[
    "review_score_x",
    "review_score_y"
], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'review_score_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 4
# ...

# %%
# 3. OPTIONAL: CHECK REMAINING _x / _y COLUMNS

[x for x in master_df.columns if "_x" in x or "_y" in x]

# %%
# 4. FINAL VALIDATION
master_df.info()

# %%
master_df.isnull().mean() * 100

# %%
master_df.shape
